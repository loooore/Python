# %%
import pandas as pd


dados = pd.read_excel("C:/Users/l50038499/Desktop/pandas 1.xlsx")
print(dados)
# Out:
#                      Bill No  RN Type Warning Flag  \
# 0     00A0792339810UBRG0001Q      NaN       Normal
# 1     00A0792339780UBRG0001Q      NaN       Normal
# 2     00A0792339790UBRG0002Q      NaN       Normal
# 3     00A0772406910UBRG0001Q      NaN       Normal
# 4     00A0772406890UBRG0001Q      NaN       Normal
# ...                      ...      ...          ...
# 2598  00D0792484190ABRG0001Q      NaN       Normal
# 2599  00D0772349780GBRG0001Q      NaN       Normal
# 2600  00D0792424320ABRG0001Q      NaN       Normal
# 2601  00D0792461390ABRG0001Q      NaN       Normal
# 2602  00D0792474940ABRG0002Q      NaN       Normal
#
#                               Action  Last Overdue Check Date Project Code  \
# 0     Waiting For X-Docking Outbound                      NaN      56A0CP2
# 1     Waiting For X-Docking Outbound                      NaN      56A0CP2
# 2     Waiting For X-Docking Outbound                      NaN      56A0CP2
# ...
