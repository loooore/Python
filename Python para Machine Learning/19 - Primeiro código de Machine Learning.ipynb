# %%
import pandas as pd

vinhos_arquivo = pd.read_csv("C:/Users/l50038499/Desktop/wine_dataset.csv")

# %%
vinhos_arquivo.head(10000)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
vinhos_arquivo['style'] = vinhos_arquivo['style'].replace('red', 0)

# %%
vinhos_arquivo['style'] = vinhos_arquivo['style'].replace('white', 1)

# %%
# Separando as variáveis entre preditoras e variáveis alvo
alvo = vinhos_arquivo['style']
resto = vinhos_arquivo.drop('style', axis = 1) # excluindo a coluna style / axis = 1 - significa q é operações na coluna

# %%
from sklearn.model_selection import train_test_split

# Criando os conjuntos de dados de treino e teste:
resto_treino, resto_teste, alvo_treino, alvo_teste = train_test_split(resto, alvo, test_size = 0.3) # 30% dos dados vão ser pra teste, 
                                                                                                    # os 70% vão ser pra treino

# %%
from sklearn.ensemble import ExtraTreesClassifier

# Criação de modelo:
modelo = ExtraTreesClassifier()
modelo.fit(resto_treino, alvo_treino)

# Imprimindo resultados:
resultado = modelo.score(resto_teste, alvo_teste)
print('Acurácia:', resultado)
# Out:
# Acurácia: 0.9989743589743589

# %%
alvo_teste[400:410]
# Out:
# 6145    1
# 632     0
# 2947    1
# 2907    1
# 2036    1
# 5324    1
# 4479    1
# 4224    1
# 5718    1
# 221     0
# Name: style, dtype: int64

# %%
resto_teste[400:410]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 6145            6.5              0.20         0.31            2.10      0.033
# 632             7.6              0.41         0.14            3.00      0.087
# 2947            7.8              0.29         0.36            7.00      0.042
# 2907            9.2              0.15         0.68            1.60      0.046
# 2036            6.6              0.16         0.32            1.40      0.035
# 5324            6.6              0.26         0.28            9.40      0.028
# 4479            7.9              0.25         0.35            6.70      0.039
# 4224            4.5              0.19         0.21            0.95      0.033
# 5718            6.5              0.40         0.31            3.50      0.046
# 221             7.4              0.53         0.26            2.00      0.101
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density    pH  sulphates  \
# ...

# %%
previsoes = modelo.predict(resto_teste[400:410])

# %%
previsoes
# Out:
# array([1, 0, 1, 1, 1, 1, 1, 1, 1, 0], dtype=int64)
